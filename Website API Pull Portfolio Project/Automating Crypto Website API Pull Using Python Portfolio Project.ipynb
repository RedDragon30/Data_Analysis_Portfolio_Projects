# %% [markdown]
# # Automating CoinMarketCap (Crypto Website) API Pull Using Python
#
# ### Data Source: [CoinMarketCap](https://coinmarketcap.com/)
# ### API Documentation: [CoinMarketCap API Documentation](https://pro.coinmarketcap.com/api/v1#section/Quick-Start-Guide)
#
# > We Will Pull **95100 samples** from cryptocurrency dataset for **4993 types** of cryptocurrency and put them in a csv file

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pandas as pd

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'100',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
#        id         name  symbol         slug  num_market_pairs  \
# 0       1      Bitcoin     BTC      bitcoin             12289
# 1    1027     Ethereum     ETH     ethereum             10462
# 2      52          XRP     XRP          xrp              1679
# 3     825  Tether USDt    USDT       tether            142128
# 4    1839          BNB     BNB          bnb              2672
# ..    ...          ...     ...          ...               ...
# 95   8425    JasmyCoin   JASMY        jasmy               316
# 96  34104       Morpho  MORPHO       morpho               148
# 97   7080         Gala    GALA         gala               536
# 98   6210  The Sandbox    SAND  the-sandbox               675
# 99   3871           AB      AB       newton                67
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2013-08-04T00:00:00.000Z
# 3   2015-02-25T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# ..                       ...
# 95  2021-02-11T00:00:00.000Z
# 96  2024-11-21T10:30:00.000Z
# 97  2020-09-16T00:00:00.000Z
# 98  2020-08-05T00:00:00.000Z
# 99  2019-04-17T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 3   [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 4   [marketplace, centralized-exchange, payments, ...           NaN
# ..                                                ...           ...
# 95  [iot, ethereum-ecosystem, dwf-labs-portfolio, ...  5.000000e+10
# 96  [defi, ethereum-ecosystem, coinbase-ventures-p...  1.000000e+09
# 97  [collectibles-nfts, gaming, binance-smart-chai...  5.000000e+10
# 98  [communications-social-media, collectibles-nft...           NaN
# 99  [mineable, marketplace, enterprise-solutions, ...  9.882366e+10
#
#     circulating_supply  total_supply  ...  quote.USD.market_cap_dominance  \
# 0         1.990932e+07  1.990932e+07  ...                         58.5846
# 1         1.207076e+08  1.207076e+08  ...                         13.4024
# 2         5.941850e+10  9.998584e+10  ...                          4.4774
# 3         1.670598e+11  1.697492e+11  ...                          4.3253
# 4         1.392875e+08  1.392875e+08  ...                          3.1111
# ..                 ...           ...  ...                             ...
# 95        4.944500e+10  5.000000e+10  ...                          0.0200
# 96        3.278350e+08  1.000000e+09  ...                          0.0197
# 97        4.570925e+10  4.570925e+10  ...                          0.0197
# 98        2.573289e+09  3.000000e+09  ...                          0.0188
# 99        7.355929e+10  9.882366e+10  ...                          0.0183
#
#     quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                         2.386227e+12            NaN
# 1                         5.175444e+11            NaN
# 2                         2.909814e+11            NaN
# 3                         1.697354e+11            NaN
# 4                         1.201390e+11            NaN
# ..                                 ...            ...
# 95                        7.803817e+08            NaN
# 96                        2.320872e+09            NaN
# 97                        8.311967e+08            NaN
# 98                        8.476232e+08            NaN
# 99                        9.486078e+08            NaN
#
#       quote.USD.last_updated  platform.id            platform.name  \
# 0   2025-08-21T06:22:00.000Z          NaN                      NaN
# 1   2025-08-21T06:22:00.000Z          NaN                      NaN
# 2   2025-08-21T06:23:00.000Z          NaN                      NaN
# 3   2025-08-21T06:22:00.000Z       1027.0                 Ethereum
# 4   2025-08-21T06:22:00.000Z          NaN                      NaN
# ..                       ...          ...                      ...
# 95  2025-08-21T06:23:00.000Z       1027.0                 Ethereum
# 96  2025-08-21T06:23:00.000Z       1027.0                 Ethereum
# 97  2025-08-21T06:23:00.000Z       1027.0                 Ethereum
# 98  2025-08-21T06:23:00.000Z       1027.0                 Ethereum
# 99  2025-08-21T06:23:00.000Z       1839.0  BNB Smart Chain (BEP20)
#
#    platform.symbol  platform.slug                      platform.token_address  \
# 0              NaN            NaN                                         NaN
# 1              NaN            NaN                                         NaN
# 2              NaN            NaN                                         NaN
# 3              ETH       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 4              NaN            NaN                                         NaN
# ..             ...            ...                                         ...
# 95             ETH       ethereum  0x7420B4b9a0110cdC71fB720908340C03F9Bc03EC
# 96             ETH       ethereum  0x58D97B57BB95320F9a05dC918Aef65434969c2B2
# 97             ETH       ethereum  0xd1d2Eb1B1e90B638588728b4130137D262C87cae
# 98             ETH       ethereum  0x3845badAde8e6dFF049820680d1F14bD3903a5d0
# 99             BNB            bnb  0x95034f653d5d161890836ad2b6b8cc49d14e029a
#
#                     timestamp
# 0  2025-08-21 08:23:42.316005
# 1  2025-08-21 08:23:42.316005
# 2  2025-08-21 08:23:42.316005
# 3  2025-08-21 08:23:42.316005
# 4  2025-08-21 08:23:42.316005
# ..                        ...
# 95 2025-08-21 08:23:42.316005
# 96 2025-08-21 08:23:42.316005
# 97 2025-08-21 08:23:42.316005
# 98 2025-08-21 08:23:42.316005
# 99 2025-08-21 08:23:42.316005
#
# [100 rows x 37 columns]

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'5000',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters) # You can put timeout(30) in session
      data = json.loads(response.text)

      # Use this if you just want to keep it in a dataframe
      df2 = pd.json_normalize(data['data'])
      df2['Timestamp'] = pd.to_datetime('now')
      df = pd.concat([df, df2])
    
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

# %%
import os 
from time import time
from time import sleep

for i in range(20):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed
# API Runner completed
# API Runner completed
# HTTPSConnectionPool(host='pro-api.coinmarketcap.com', port=443): Max retries exceeded with url: /v1/cryptocurrency/listings/latest?start=1&limit=5000&convert=USD (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002341CD35640>: Failed to resolve 'pro-api.coinmarketcap.com' ([Errno 11001] getaddrinfo failed)"))
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed
# API Runner completed

# %%
df
# Out:
#          id                name  symbol                slug  num_market_pairs  \
# 0         1             Bitcoin     BTC             bitcoin             12289
# 1      1027            Ethereum     ETH            ethereum             10462
# 2        52                 XRP     XRP                 xrp              1679
# 3       825         Tether USDt    USDT              tether            142128
# 4      1839                 BNB     BNB                 bnb              2672
# ...     ...                 ...     ...                 ...               ...
# 4995  34616            Fleabone    BONE        fleabone-eth                 3
# 4996  13827     SavePlanetEarth     SPE     saveplanetearth                11
# 4997  37379              Hoodog  HOODOG              hoodog                 1
# 4998  34650  Seraph by Virtuals  SERAPH  seraph-by-virtuals                10
# 4999  17480           ChainPort   PORTX           chainport                14
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2013-08-04T00:00:00.000Z
# 3     2015-02-25T00:00:00.000Z
# 4     2017-07-25T00:00:00.000Z
# ...                        ...
# 4995  2024-12-13T11:30:47.000Z
# 4996  2021-04-19T00:00:00.000Z
# 4997  2025-07-16T07:26:01.000Z
# 4998  2024-12-16T11:22:26.000Z
# 4999  2022-01-19T14:55:26.000Z
#
#                                                    tags    max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2     [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 3     [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 4     [marketplace, centralized-exchange, payments, ...           NaN
# ...                                                 ...           ...
# 4995                        [memes, ethereum-ecosystem]  4.206900e+11
# 4996                               [ethereum-ecosystem]  1.000000e+09
# 4997                               [ethereum-ecosystem]  1.000000e+15
# 4998  [ai-big-data, base-ecosystem, ai-agents, virtu...  1.000000e+09
# 4999  [defi, privacy, ethereum-ecosystem, dao-maker,...           NaN
#
#       circulating_supply                   total_supply  ...  \
# 0           1.990932e+07                     19909321.0  ...
# 1           1.207076e+08               120707592.009596  ...
# 2           5.941850e+10                  99985837887.0  ...
# 3           1.670598e+11            169749161072.138367  ...
# 4           1.392875e+08                    139287514.5  ...
# ...                  ...                            ...  ...
# 4995        0.000000e+00                   420690000000  ...
# 4996        0.000000e+00                      587383660  ...
# 4997        0.000000e+00               1000000000000000  ...
# 4998        0.000000e+00                     1000000000  ...
# 4999        0.000000e+00  679814605447146766721875968.0  ...
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                           2.386227e+12            NaN
# 1                           5.175444e+11            NaN
# 2                           2.909814e+11            NaN
# 3                           1.697354e+11            NaN
# 4                           1.201390e+11            NaN
# ...                                  ...            ...
# 4995                        1.336687e+05            NaN
# 4996                        7.973628e+06            NaN
# 4997                        9.038129e+04            NaN
# 4998                        6.161496e+05            NaN
# 4999                        5.371934e+23      3008696.0
#
#         quote.USD.last_updated  platform.id  platform.name  platform.symbol  \
# 0     2025-08-21T06:22:00.000Z          NaN            NaN              NaN
# 1     2025-08-21T06:22:00.000Z          NaN            NaN              NaN
# 2     2025-08-21T06:23:00.000Z          NaN            NaN              NaN
# 3     2025-08-21T06:22:00.000Z       1027.0       Ethereum              ETH
# 4     2025-08-21T06:22:00.000Z          NaN            NaN              NaN
# ...                        ...          ...            ...              ...
# 4995  2025-08-21T06:44:00.000Z       1027.0       Ethereum              ETH
# 4996  2025-08-21T06:44:00.000Z       1027.0       Ethereum              ETH
# 4997  2025-08-21T06:44:00.000Z       1027.0       Ethereum              ETH
# 4998  2025-08-21T06:44:00.000Z      27716.0           Base              TBA
# 4999  2025-08-21T06:43:00.000Z       1027.0       Ethereum              ETH
#
#      platform.slug                      platform.token_address  \
# 0              NaN                                         NaN
# 1              NaN                                         NaN
# 2              NaN                                         NaN
# 3         ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 4              NaN                                         NaN
# ...            ...                                         ...
# 4995      ethereum  0x7076De6fF1d91e00Be7E92458089C833De99E22E
# 4996      ethereum  0x4b91dfa774acde7ed70e93a6438363feaaa40f54
# 4997      ethereum  0x9bf8FBCEe83e30014B3c48DF4e6eb1D3F08df4B8
# 4998          base  0x4f81837c2f4a189a0b69370027cc2627d93785b4
# 4999      ethereum  0x104f3152d8ebfc3f679392977356962ff36566ac
#
#                       timestamp                  Timestamp
# 0    2025-08-21 08:23:42.316005                        NaT
# 1    2025-08-21 08:23:42.316005                        NaT
# 2    2025-08-21 08:23:42.316005                        NaT
# 3    2025-08-21 08:23:42.316005                        NaT
# 4    2025-08-21 08:23:42.316005                        NaT
# ...                         ...                        ...
# 4995                        NaT 2025-08-21 08:45:00.141930
# 4996                        NaT 2025-08-21 08:45:00.141930
# 4997                        NaT 2025-08-21 08:45:00.141930
# 4998                        NaT 2025-08-21 08:45:00.141930
# 4999                        NaT 2025-08-21 08:45:00.141930
#
# [95100 rows x 38 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
df
# Out:
#          id                name  symbol                slug  num_market_pairs  \
# 0         1             Bitcoin     BTC             bitcoin             12289
# 1      1027            Ethereum     ETH            ethereum             10462
# 2        52                 XRP     XRP                 xrp              1679
# 3       825         Tether USDt    USDT              tether            142128
# 4      1839                 BNB     BNB                 bnb              2672
# ...     ...                 ...     ...                 ...               ...
# 4995  34616            Fleabone    BONE        fleabone-eth                 3
# 4996  13827     SavePlanetEarth     SPE     saveplanetearth                11
# 4997  37379              Hoodog  HOODOG              hoodog                 1
# 4998  34650  Seraph by Virtuals  SERAPH  seraph-by-virtuals                10
# 4999  17480           ChainPort   PORTX           chainport                14
#
#                     date_added  \
# 0     2010-07-13T00:00:00.000Z
# 1     2015-08-07T00:00:00.000Z
# 2     2013-08-04T00:00:00.000Z
# 3     2015-02-25T00:00:00.000Z
# 4     2017-07-25T00:00:00.000Z
# ...                        ...
# 4995  2024-12-13T11:30:47.000Z
# 4996  2021-04-19T00:00:00.000Z
# 4997  2025-07-16T07:26:01.000Z
# 4998  2024-12-16T11:22:26.000Z
# 4999  2022-01-19T14:55:26.000Z
#
#                                                    tags           max_supply  \
# 0     [mineable, pow, sha-256, store-of-value, state...         21000000.000
# 1     [pos, smart-contracts, ethereum-ecosystem, coi...                  NaN
# 2     [medium-of-exchange, enterprise-solutions, xrp...     100000000000.000
# 3     [stablecoin, asset-backed-stablecoin, usd-stab...                  NaN
# 4     [marketplace, centralized-exchange, payments, ...                  NaN
# ...                                                 ...                  ...
# 4995                        [memes, ethereum-ecosystem]     420690000000.000
# 4996                               [ethereum-ecosystem]       1000000000.000
# 4997                               [ethereum-ecosystem] 1000000000000000.000
# 4998  [ai-big-data, base-ecosystem, ai-agents, virtu...       1000000000.000
# 4999  [defi, privacy, ethereum-ecosystem, dao-maker,...                  NaN
#
#       circulating_supply                    total_supply  ...  \
# 0           19909321.000                    19909321.000  ...
# 1          120707592.010                   120707592.010  ...
# 2        59418500720.000                 99985837887.000  ...
# 3       167059822574.779                169749161072.138  ...
# 4          139287514.500                   139287514.500  ...
# ...                  ...                             ...  ...
# 4995               0.000                    420690000000  ...
# 4996               0.000                       587383660  ...
# 4997               0.000                1000000000000000  ...
# 4998               0.000                      1000000000  ...
# 4999               0.000 679814605447146766721875968.000  ...
#
#       quote.USD.fully_diluted_market_cap  quote.USD.tvl  \
# 0                      2386226521620.180            NaN
# 1                       517544417075.060            NaN
# 2                       290981432579.640            NaN
# 3                       169735407379.490            NaN
# 4                       120138963709.840            NaN
# ...                                  ...            ...
# 4995                          133668.720            NaN
# 4996                         7973627.780            NaN
# 4997                           90381.290            NaN
# 4998                          616149.580            NaN
# 4999        537193429450849282686976.000    3008696.000
#
#         quote.USD.last_updated  platform.id  platform.name  platform.symbol  \
# 0     2025-08-21T06:22:00.000Z          NaN            NaN              NaN
# 1     2025-08-21T06:22:00.000Z          NaN            NaN              NaN
# 2     2025-08-21T06:23:00.000Z          NaN            NaN              NaN
# 3     2025-08-21T06:22:00.000Z     1027.000       Ethereum              ETH
# 4     2025-08-21T06:22:00.000Z          NaN            NaN              NaN
# ...                        ...          ...            ...              ...
# 4995  2025-08-21T06:44:00.000Z     1027.000       Ethereum              ETH
# 4996  2025-08-21T06:44:00.000Z     1027.000       Ethereum              ETH
# 4997  2025-08-21T06:44:00.000Z     1027.000       Ethereum              ETH
# 4998  2025-08-21T06:44:00.000Z    27716.000           Base              TBA
# 4999  2025-08-21T06:43:00.000Z     1027.000       Ethereum              ETH
#
#      platform.slug                      platform.token_address  \
# 0              NaN                                         NaN
# 1              NaN                                         NaN
# 2              NaN                                         NaN
# 3         ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 4              NaN                                         NaN
# ...            ...                                         ...
# 4995      ethereum  0x7076De6fF1d91e00Be7E92458089C833De99E22E
# 4996      ethereum  0x4b91dfa774acde7ed70e93a6438363feaaa40f54
# 4997      ethereum  0x9bf8FBCEe83e30014B3c48DF4e6eb1D3F08df4B8
# 4998          base  0x4f81837c2f4a189a0b69370027cc2627d93785b4
# 4999      ethereum  0x104f3152d8ebfc3f679392977356962ff36566ac
#
#                       timestamp                  Timestamp
# 0    2025-08-21 08:23:42.316005                        NaT
# 1    2025-08-21 08:23:42.316005                        NaT
# 2    2025-08-21 08:23:42.316005                        NaT
# 3    2025-08-21 08:23:42.316005                        NaT
# 4    2025-08-21 08:23:42.316005                        NaT
# ...                         ...                        ...
# 4995                        NaT 2025-08-21 08:45:00.141930
# 4996                        NaT 2025-08-21 08:45:00.141930
# 4997                        NaT 2025-08-21 08:45:00.141930
# 4998                        NaT 2025-08-21 08:45:00.141930
# 4999                        NaT 2025-08-21 08:45:00.141930
#
# [95100 rows x 38 columns]

# %%
df.to_csv('crypto_dataset.csv', index=False)
